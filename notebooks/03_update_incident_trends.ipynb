# %% [markdown]
# # 03 Update Incident Trends
#
# This notebook inspects the pre/post-2023 comparison table used in the write-up and charts.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
pre_post = pd.read_csv(ROOT / 'data' / 'processed' / 'pre_post_genai_summary.csv')

pre_post

# %%
share_rows = pre_post[pre_post['metric'] == 'share_of_incidents'].copy()
share_rows['value_percent'] = share_rows['value'].astype(float) * 100
share_rows[['period', 'category', 'value_percent', 'notes']]
