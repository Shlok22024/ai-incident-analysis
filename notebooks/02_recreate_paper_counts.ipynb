# %% [markdown]
# # 02 Recreate Paper Counts
#
# This notebook compares the recreated category counts with the paper reference counts stored in `data/raw/original_paper_reference_counts.csv`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
app_summary = pd.read_csv(ROOT / 'data' / 'processed' / 'application_area_summary.csv')
ethics_summary = pd.read_csv(ROOT / 'data' / 'processed' / 'ethics_issue_summary.csv')

app_summary.head(10)

# %%
ethics_summary.head(10)
