# %% [markdown]
# # 04 Visualizations
#
# This notebook previews the generated chart files saved by `src/make_charts.py`.

# %%
from pathlib import Path
from IPython.display import Image, display

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
figures_dir = ROOT / 'outputs' / 'figures'
figure_names = [
    'portfolio_summary_card.png',
    'incidents_by_year.png',
    'top_application_areas.png',
    'top_ethics_issues.png',
    'pre_post_genai_comparison.png',
]

for figure_name in figure_names:
    display(Image(filename=str(figures_dir / figure_name)))
